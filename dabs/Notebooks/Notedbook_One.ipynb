# %%
print("Hello World1")

# %%
print("I'm Fine")

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

data = [
    (1, "Alice", 29, "Cardiology", 75000),
    (2, "Bob", 35, "Neurology", 82000),
    (3, "Charlie", 42, "Orthopedics", 90000),
    (4, "David", 31, "Pediatrics", 68000),
    (5, "Eva", 27, "Dermatology", 70000),
    (6, "Frank", 45, "Oncology", 95000),
    (7, "Grace", 38, "Radiology", 88000),
    (8, "Helen", 33, "Gynecology", 76000),
    (9, "Ian", 41, "Urology", 87000),
    (10, "Jane", 26, "ENT", 65000)
]

columns = ["emp_id", "name", "age", "department", "salary"]

df = spark.createDataFrame(data, columns)
df.show()

# %%
from pyspark.sql.functions import col
df.filter(col("age") > 30).show()

# %%
df.filter(col("salary") > 80000).show()

# %%
df.filter(col("department") == "Cardiology").show()
